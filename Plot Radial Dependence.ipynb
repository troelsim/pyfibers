# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from pyfibers.modes.lekien import LeKienRadMode
import numpy as np

# %%
Rs = np.linspace(0.01,20,201)
m = LeKienRadMode(1, 1.45, 1.0, 0.77, 1.05, pol=1)
e_z = m.e_z(0.3,0.3,2.1)
e_z2 = m.e_z_cladding(0.3,0.3,2.1)
print e_z.dtype
print e_z, e_z2
e_zs = m.e_z(Rs,0,0.0)
print e_zs.dtype
plt.plot(Rs,np.imag(e_zs))
plt.plot(Rs,np.real(e_zs))
# Out:
# complex128
# (0.123597697292+0.0944501600178j) (0.158954622722+0j)
# complex128
